# %%
import pandas as pd
import numpy as np
from datetime import datetime
import re

# %%
def standardize_county_name(county):
    """
    Standardize Washington county names to handle all variations
    """
    if pd.isna(county):
        return 'Unknown'

    county = str(county).upper().strip()

    # Remove common suffixes and prefixes
    county = county.replace(' COUNTY', '')
    county = county.replace('CITY OF ', '')

    # Dictionary of corrections for Washington counties
    corrections = {
        # Case variations
        'Clark': 'CLARK',
        'CLALLAM': 'CLALLAM',
        'Walla Walla': 'WALLA WALLA',
        'King': 'KING',
        'KING': 'KING',
        'Kings': 'KING',
        'THURSTON': 'THURSTON',
        'Thurston': 'THURSTON',
        'SPOKANE': 'SPOKANE',
        'Spokane': 'SPOKANE',

        # Spacing and formatting
        'GRAYS HARBOR': 'GRAYS HARBOR',
        'GRAYSHARBOR': 'GRAYS HARBOR',
        'Grays Harbor': 'GRAYS HARBOR',

        # Common misspellings
        'WAHKIAKUM': 'WAHKIAKUM',
        'WAHKIAKIMI': 'WAHKIAKUM',
        'Wahkiakum': 'WAHKIAKUM',

        # Remove districts
        'District of Columbia': 'COLUMBIA',
        'PRINCE GEORGE\'S': 'PRINCE GEORGE',

        # Standardize variations
        'ASOTIN': 'ASOTIN',
        'Asotin': 'ASOTIN',
        'BENTON': 'BENTON',
        'Benton': 'BENTON',
        'CHELAN': 'CHELAN',
        'Chelan': 'CHELAN',
        'CLACKAMAS': 'CLACKAMAS',
        'COWLITZ': 'COWLITZ',
        'Cowlitz': 'COWLITZ',
        'DOUGLAS': 'DOUGLAS',
        'Douglas': 'DOUGLAS',
        'FERRY': 'FERRY',
        'Ferry': 'FERRY',
        'FRANKLIN': 'FRANKLIN',
        'Franklin': 'FRANKLIN',
        'GRANT': 'GRANT',
        'Grant': 'GRANT',
        'ISLAND': 'ISLAND',
        'Island': 'ISLAND',
        'JEFFERSON': 'JEFFERSON',
        'Jefferson': 'JEFFERSON',
        'KITSAP': 'KITSAP',
        'Kitsap': 'KITSAP',
        'KITTITAS': 'KITTITAS',
        'Kittitas': 'KITTITAS',
        'KLICKITAT': 'KLICKITAT',
        'Klickitat': 'KLICKITAT',
        'LEWIS': 'LEWIS',
        'Lewis': 'LEWIS',
        'LINCOLN': 'LINCOLN',
        'Lincoln': 'LINCOLN',
        'MASON': 'MASON',
        'Mason': 'MASON',
        'OKANOGAN': 'OKANOGAN',
        'Okanogan': 'OKANOGAN',
        'PACIFIC': 'PACIFIC',
        'Pacific': 'PACIFIC',
        'PEND OREILLE': 'PEND OREILLE',
        'Pend Oreille': 'PEND OREILLE',
        'PIERCE': 'PIERCE',
        'Pierce': 'PIERCE',
        'SAN JUAN': 'SAN JUAN',
        'San Juan': 'SAN JUAN',
        'SKAGIT': 'SKAGIT',
        'Skagit': 'SKAGIT',
        'SKAMANIA': 'SKAMANIA',
        'Skamania': 'SKAMANIA',
        'SNOHOMISH': 'SNOHOMISH',
        'Snohomish': 'SNOHOMISH',
        'STEVENS': 'STEVENS',
        'Stevens': 'STEVENS',
        'WHATCOM': 'WHATCOM',
        'Whatcom': 'WHATCOM',
        'WHITMAN': 'WHITMAN',
        'Whitman': 'WHITMAN',
        'YAKIMA': 'YAKIMA',
        'Yakima': 'YAKIMA',

        # Remove non-Washington counties
        'New York': 'OTHER',
        'Los Angeles': 'OTHER',
        'Sacramento': 'OTHER',
        'Alameda': 'OTHER',
        'San Mateo': 'OTHER',
        'Fairfax (city)': 'OTHER',
        'Blue Earth': 'OTHER',
        'Suffolk': 'OTHER',
        'Arlington': 'OTHER',
        'Montgomery': 'OTHER',
        'Hennepin': 'OTHER',
        'Dallas': 'OTHER',
        'Harris': 'OTHER',
        'Hudson': 'OTHER',
        'Lake': 'OTHER',
        'St. Louis': 'OTHER',
        'Marin': 'OTHER',
        'Various': 'OTHER'
    }

    return corrections.get(county, county)

# %%
def clean_campaign_finance_data(df):
    """
    Clean and preprocess Washington state campaign finance data
    """
    df_clean = df.copy()

    # 1. Handle Missing Values
    numeric_columns = [
        'contributions_amount', 'carryforward_amount', 'expenditures_amount',
        'loans_amount', 'pledges_amount', 'debts_amount',
        'independent_expenditures_for_amount', 'independent_expenditures_against_amount'
    ]
    df_clean[numeric_columns] = df_clean[numeric_columns].fillna(0)

    categorical_columns = [
        'filer_type', 'filing_type', 'candidate_committee_status',
        'committee_category', 'political_committee_type', 'party',
        'election_status', 'ballot_committee'
    ]
    df_clean[categorical_columns] = df_clean[categorical_columns].fillna('Unknown')

    # 2. Date Processing
    date_columns = ['registered', 'declared', 'withdrew', 'discontinued', 'receipt_date', 'election_date']
    for col in date_columns:
        df_clean[col] = pd.to_datetime(df_clean[col], errors='coerce')

    # 3. Standardize County Names
    df_clean['committee_county'] = df_clean['committee_county'].apply(standardize_county_name)

    # 4. Define Washington Regions
    wa_regions = {
        'Puget Sound': ['KING', 'PIERCE', 'SNOHOMISH', 'KITSAP'],
        'Western WA': ['CLARK', 'COWLITZ', 'GRAYS HARBOR', 'LEWIS',
                      'PACIFIC', 'WAHKIAKUM', 'THURSTON', 'MASON'],
        'Eastern WA': ['SPOKANE', 'WHITMAN', 'ADAMS', 'LINCOLN',
                      'FERRY', 'STEVENS', 'PEND OREILLE'],
        'Central WA': ['YAKIMA', 'BENTON', 'FRANKLIN', 'GRANT',
                      'DOUGLAS', 'CHELAN', 'OKANOGAN', 'KITTITAS'],
        'Coastal': ['CLALLAM', 'JEFFERSON', 'PACIFIC', 'GRAYS HARBOR',
                   'WHATCOM', 'SKAGIT', 'SAN JUAN', 'ISLAND']
    }

    def get_wa_region(county):
        for region, counties in wa_regions.items():
            if county in counties:
                return region
        return 'Other'

    df_clean['region'] = df_clean['committee_county'].apply(get_wa_region)

    # 5. Create Derived Fields
    df_clean['total_financial_activity'] = (
        df_clean['contributions_amount'] +
        df_clean['expenditures_amount'] +
        df_clean['loans_amount']
    )

    df_clean['contribution_expenditure_ratio'] = np.where(
        df_clean['expenditures_amount'] > 0,
        df_clean['contributions_amount'] / df_clean['expenditures_amount'],
        0
    )

    df_clean['is_active'] = np.where(
        (df_clean['withdrew'].isna()) &
        (df_clean['discontinued'].isna()) &
        (df_clean['active_candidate'] == True),
        1, 0
    )

    # 6. Data Validation
    for col in numeric_columns:
        df_clean = df_clean[df_clean[col] >= 0]

    # 7. Time-based Features
    # df_clean['year'] = df_clean['receipt_date'].dt.year
    # df_clean['month'] = df_clean['receipt_date'].dt.month
    # df_clean['quarter'] = df_clean['receipt_date'].dt.quarter

    # 8. Contribution Categories
    df_clean['contribution_category'] = pd.cut(
        df_clean['contributions_amount'],
        bins=[0, 1000, 5000, 10000, 50000, float('inf')],
        labels=['Small', 'Medium', 'Large', 'Very Large', 'Mega']
    )

    # # 9. Data Type Optimization
    # boolean_columns = ['active_candidate', ]
    # for col in boolean_columns:
    #     df_clean[col] = df_clean[col].map({'Y': True, 'N': False})

    # df_clean[categorical_columns] = df_clean[categorical_columns].astype('category')

    return df_clean

# %%
data_path = '/content/drive/MyDrive/VAD_Final_Project/'
# Read the data
df_new = pd.read_csv(data_path+'campaign_finance_data.csv')
# Out:
# <ipython-input-111-220dc2127d9b>:3: DtypeWarning: Columns (3,4,5,6,10,12,19,21,28,29,32,33,34,35,39,40,41,42,43,44,45,46,48,49,50,51,52,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_new = pd.read_csv(data_path+'campaign_finance_data.csv')

# %%
df_new_clean1 = df_new[~df_new.contributions_amount.isnull()]

# %%
df_new_clean1_copy = df_new_clean1.copy()

# %%
df_new_clean2_main = df_new_clean1_copy[~df_new_clean1_copy['committee_county'].isnull()]
# df_new_clean2_main = df_new_clean2_main[df_new_clean2_main['active_candidate'] == True]

# %%
cleaned_data = clean_campaign_finance_data(df_new_clean2_main)
# Out:
# <ipython-input-110-5abe6fb76746>:25: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_clean[col] = pd.to_datetime(df_clean[col], errors='coerce')
# <ipython-input-110-5abe6fb76746>:25: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_clean[col] = pd.to_datetime(df_clean[col], errors='coerce')
# <ipython-input-110-5abe6fb76746>:25: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_clean[col] = pd.to_datetime(df_clean[col], errors='coerce')
# <ipython-input-110-5abe6fb76746>:25: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_clean[col] = pd.to_datetime(df_clean[col], errors='coerce')

# %%
cleaned_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10148 entries, 0 to 52265
# Data columns (total 81 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   id                                       10148 non-null  object
#  1   filer_id                                 10148 non-null  object
#  2   filer_type                               10148 non-null  object
#  3   registered                               9801 non-null   datetime64[ns]
#  4   declared                                 3403 non-null   datetime64[ns]
#  5   withdrew                                 5 non-null      datetime64[ns]
#  6   discontinued                             20 non-null     datetime64[ns]
#  7   filing_type                              10148 non-null  object
#  8   receipt_date                             10147 non-null  datetime64[ns]
#  9   election_year                            10148 non-null  int64
#  10  candidate_committee_status               10148 non-null  object
#  11  filer_name                               10148 non-null  object
#  12  committee_acronym                        331 non-null    object
#  13  committee_address                        10147 non-null  object
#  14  committee_city                           10147 non-null  object
#  15  committee_county                         10148 non-null  object
#  16  committee_state                          7064 non-null   object
#  17  committee_zip                            10148 non-null  object
#  18  committee_email                          9322 non-null   object
#  19  candidate_email                          9600 non-null   object
#  20  candidate_committee_phone                6933 non-null   object
#  21  office                                   9802 non-null   object
#  22  office_code                              9802 non-null   float64
#  23  jurisdiction                             10148 non-null  object
#  24  jurisdiction_code                        10139 non-null  float64
#  25  jurisdiction_county                      10148 non-null  object
#  26  jurisdiction_type                        10146 non-null  object
#  27  jurisdiction_voters                      8182 non-null   float64
#  28  jurisdiction_reporting_code              9795 non-null   object
#  29  jurisdiction_reporting_requirement       9802 non-null   object
#  30  committee_category                       10148 non-null  object
#  31  political_committee_type                 10148 non-null  object
#  32  bonafide_committee                       2 non-null      object
#  33  bonafide_type                            2 non-null      object
#  34  position                                 3525 non-null   object
#  35  party_code                               7270 non-null   object
#  36  party                                    10148 non-null  object
#  37  election_date                            10120 non-null  datetime64[ns]
#  38  reporting_option                         7065 non-null   object
#  39  active_candidate                         9802 non-null   object
#  40  on_primary_election_ballot               3822 non-null   object
#  41  on_general_election_ballot               3765 non-null   object
#  42  primary_election_status                  8827 non-null   object
#  43  general_election_status                  7131 non-null   object
#  44  election_status                          10148 non-null  object
#  45  exempt_nonexempt                         2 non-null      object
#  46  ballot_committee                         10148 non-null  object
#  47  ballot_proposal_count                    346 non-null    float64
#  48  ballot_number                            174 non-null    object
#  49  ballot_title                             288 non-null    object
#  50  for_or_against                           346 non-null    object
#  51  ballot_proposal_detail                   346 non-null    object
#  52  other_pac                                12 non-null     object
#  53  treasurer_address                        10018 non-null  object
#  54  treasurer_city                           10018 non-null  object
#  55  treasurer_state                          6931 non-null   object
#  56  treasurer_zip                            10018 non-null  object
#  57  treasurer_phone                          6407 non-null   object
#  58  contributions_amount                     10148 non-null  float64
#  59  carryforward_amount                      10148 non-null  float64
#  60  expenditures_amount                      10148 non-null  float64
#  61  loans_amount                             10148 non-null  float64
#  62  pledges_amount                           10148 non-null  float64
#  63  debts_amount                             10148 non-null  float64
#  64  independent_expenditures_for_amount      10148 non-null  float64
#  65  independent_expenditures_against_amount  10148 non-null  float64
#  66  url                                      10148 non-null  object
#  67  committee_id                             10148 non-null  float64
#  68  person_id                                10148 non-null  float64
#  69  candidacy_id                             9802 non-null   float64
#  70  fund_id                                  10148 non-null  float64
#  71  legislative_district                     2473 non-null   float64
#  72  treasurer_name                           10147 non-null  object
#  73  pac_type                                 10148 non-null  object
#  74  continuing                               346 non-null    object
#  75  updated_at                               10148 non-null  object
#  76  region                                   10148 non-null  object
#  77  total_financial_activity                 10148 non-null  float64
#  78  contribution_expenditure_ratio           10148 non-null  float64
#  79  is_active                                10148 non-null  int64
#  80  contribution_category                    8974 non-null   category
# dtypes: category(1), datetime64[ns](6), float64(19), int64(2), object(53)
# memory usage: 6.3+ MB

# %%
# Define the 10 election periods (adjust the years as necessary)
# election_periods = [2012, 2014, 2016, 2018, 2020, 2022, 2024]

# Filter the dataset for the specified election periods
# cleaned_data_2 = cleaned_data[cleaned_data['election_year'].isin(election_periods)]

# %%
columns_to_keep = [
    'id',
    'filer_name',
    'filer_type',
    'filing_type',
    'receipt_date',
    'election_year',
    'contributions_amount',
    'expenditures_amount',
    'total_financial_activity',
    'contribution_expenditure_ratio',
    'committee_category',
    'contribution_category',
    'committee_state',
    'committee_county',
    'party',
    'region',
    'is_active'
]

# Filter the dataset to keep only these columns
cleaned_data_2 = cleaned_data[columns_to_keep]
cleaned_data_2 = cleaned_data_2[~(cleaned_data_2.receipt_date == '1899-12-31')]
cleaned_data_2 = cleaned_data_2[~cleaned_data_2.contribution_category.isnull()]

# Save the cleaned dataset to an Excel file
# cleaned_file_path = 'cleaned_campaign_finance_data_reduced_updated.xlsx'
# cleaned_data_2.to_excel(cleaned_file_path, index=False)

# %%
# cleaned_file_path2 = 'cleaned_campaign_finance_data_reduced.csv'
# cleaned_data_2.to_csv(cleaned_file_path2, index=False)

# %%
cleaned_data_2.head(5)
# Out:
#                  id                                         filer_name  \
# 0     ca-2024-93123                               Kevin W. Van De Wege
# 18   ca-2024-689015                                       My-Linh Thai
# 19  ca-2024-3296585                                     Wayne Fournier
# 33      co-2024-425  ALLIANCE FOR A COMPETITIVE ECONOMY OF GREATER ...
# 34  ca-2024-3310897                                     Rita Cole Hall
#
#    filer_type filing_type receipt_date  election_year  contributions_amount  \
# 0          CA  Electronic   2021-01-19           2024              32202.89
# 18         CA  Electronic   2023-01-02           2024              86624.46
# 19         CA  Electronic   2024-02-12           2024              18006.00
# 33         CO  Electronic   2009-06-01           2024              15500.00
# 34         CA  Electronic   2024-06-28           2024               1395.99
#
#     expenditures_amount  total_financial_activity  \
# 0              37509.32                  69712.21
# 18             76428.15                 163052.61
# 19              9411.91                  27417.91
# 33             12916.54                  28416.54
# 34              1002.35                   2654.33
#
#     contribution_expenditure_ratio committee_category contribution_category  \
# 0                         0.858530          Candidate            Very Large
# 18                        1.133410          Candidate                  Mega
# 19                        1.913108          Candidate            Very Large
# 33                        1.200012              Other            Very Large
# 34                        1.392717          Candidate                Medium
#
#    committee_state committee_county       party       region  is_active
# 0               WA          CLALLAM  DEMOCRATIC      Coastal          1
# 18              WA             KING     Unknown  Puget Sound          1
# 19              WA         THURSTON  DEMOCRATIC   Western WA          1
# 33              WA          VARIOUS     Unknown        Other          0
# 34              WA          PACIFIC  REPUBLICAN   Western WA          1

# %%
cleaned_data_2.committee_state.unique()
# Out:
# array(['WA', 'Washington', 'Wa', 'wa', 'United States (+1)', 'WASHINGTON',
#        'WASHINGTON (WA)', nan, 'WA.', 'Arizona', 'USA', 'WA - WASHINGTON',
#        'United States (1)', 'King', 'WAStates (1)', 'washington',
#        'Waahington', 'Wa.', 'Washington state', 'Walla', 'United States',
#        'Franklin', 'WASINGTON', 'Washington(WA)', 'WA - Washington', 'CA',
#        'US', 'Washinton'], dtype=object)

# %%
cleaned_data_2.contributions_amount.unique()
# Out:
# array([32202.89, 86624.46, 18006.  , ...,  1993.49,  5188.37,  5565.89])

# %%
cleaned_data_2[cleaned_data_2.receipt_date.isnull()]

# %%
# Out:
# (1173, 17)

# %%
cleaned_data_2.election_year.max()
# Out:
# 2029

# %%
cleaned_data_2.shape
# Out:
# (10147, 17)

# %%
cleaned_data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8974 entries, 0 to 52265
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              8974 non-null   object
#  1   filer_name                      8974 non-null   object
#  2   filer_type                      8974 non-null   object
#  3   filing_type                     8974 non-null   object
#  4   receipt_date                    8973 non-null   datetime64[ns]
#  5   election_year                   8974 non-null   int64
#  6   contributions_amount            8974 non-null   float64
#  7   expenditures_amount             8974 non-null   float64
#  8   total_financial_activity        8974 non-null   float64
#  9   contribution_expenditure_ratio  8974 non-null   float64
#  10  committee_category              8974 non-null   object
#  11  contribution_category           8974 non-null   category
#  12  committee_county                8974 non-null   object
#  13  party                           8974 non-null   object
#  14  region                          8974 non-null   object
#  15  is_active                       8974 non-null   int64
# dtypes: category(1), datetime64[ns](1), float64(4), int64(2), object(8)
# memory usage: 1.1+ MB

# %%
df_new_clean1_copy.active_candidate.value_counts()
# Out:
# active_candidate
# True     10962
# False      123
# Name: count, dtype: int64

# %%
cleaned_data = clean_campaign_finance_data(df_new)
# Out:
# <ipython-input-13-4416e1b4735a>:25: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_clean[col] = pd.to_datetime(df_clean[col], errors='coerce')
# <ipython-input-13-4416e1b4735a>:25: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_clean[col] = pd.to_datetime(df_clean[col], errors='coerce')
# <ipython-input-13-4416e1b4735a>:25: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_clean[col] = pd.to_datetime(df_clean[col], errors='coerce')
# <ipython-input-13-4416e1b4735a>:25: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_clean[col] = pd.to_datetime(df_clean[col], errors='coerce')

# %%
cleaned_data[cleaned_data.committ.isnull()]
# Out:
# Empty DataFrame
# Columns: [id, filer_id, filer_type, registered, declared, withdrew, discontinued, filing_type, receipt_date, election_year, candidate_committee_status, filer_name, committee_acronym, committee_address, committee_city, committee_county, committee_state, committee_zip, committee_email, candidate_email, candidate_committee_phone, office, office_code, jurisdiction, jurisdiction_code, jurisdiction_county, jurisdiction_type, jurisdiction_voters, jurisdiction_reporting_code, jurisdiction_reporting_requirement, committee_category, political_committee_type, bonafide_committee, bonafide_type, position, party_code, party, election_date, reporting_option, active_candidate, on_primary_election_ballot, on_general_election_ballot, primary_election_status, general_election_status, election_status, exempt_nonexempt, ballot_committee, ballot_proposal_count, ballot_number, ballot_title, for_or_against, ballot_proposal_detail, other_pac, treasurer_address, treasurer_city, treasurer_state, treasurer_zip, treasurer_phone, contributions_amount, carryforward_amount, expenditures_amount, loans_amount, pledges_amount, debts_amount, independent_expenditures_for_amount, independent_expenditures_against_amount, url, committee_id, person_id, candidacy_id, fund_id, legislative_district, treasurer_name, pac_type, continuing, updated_at, region, total_financial_activity, contribution_expenditure_ratio, is_active, year, month, quarter, contribution_category]
# Index: []
#
# [0 rows x 84 columns]

# %%
cleaned_data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51203 entries, 0 to 52265
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              51203 non-null  object
#  1   filer_name                      51203 non-null  object
#  2   receipt_date                    43784 non-null  datetime64[ns]
#  3   election_year                   51203 non-null  int64
#  4   contributions_amount            51203 non-null  float64
#  5   expenditures_amount             51203 non-null  float64
#  6   total_financial_activity        51203 non-null  float64
#  7   contribution_expenditure_ratio  51203 non-null  float64
#  8   committee_category              51203 non-null  category
#  9   contribution_category           18167 non-null  category
#  10  committee_state                 30251 non-null  object
#  11  committee_county                51203 non-null  object
#  12  party                           51203 non-null  category
#  13  region                          51203 non-null  object
#  14  receipt_date                    43784 non-null  datetime64[ns]
#  15  is_active                       51203 non-null  int64
# dtypes: category(3), datetime64[ns](2), float64(4), int64(2), object(5)
# memory usage: 5.6+ MB

# %%
df_camp_clean[df_camp_clean['committee_id'] == 12199][[ 'committee_acronym',
       'committee_address', 'committee_city', 'committee_county',
       'committee_state', 'committee_zip', 'committee_email',
       'candidate_email']]
# Out:
#       committee_acronym  committee_address committee_city committee_county  \
# 27767               NaN  22056 Se 304Th St  Black Diamond             King
#
#       committee_state committee_zip    committee_email    candidate_email
# 27767             NaN         98010  RJMAURO99@MSN.COM  rjmauro99@msn.com

# %%
df_camp_clean.columns
# Out:
# Index(['id', 'filer_id', 'filer_type', 'registered', 'declared', 'withdrew',
#        'discontinued', 'filing_type', 'receipt_date', 'election_year',
#        'candidate_committee_status', 'filer_name', 'committee_acronym',
#        'committee_address', 'committee_city', 'committee_county',
#        'committee_state', 'committee_zip', 'committee_email',
#        'candidate_email', 'candidate_committee_phone', 'office', 'office_code',
#        'jurisdiction', 'jurisdiction_code', 'jurisdiction_county',
#        'jurisdiction_type', 'jurisdiction_voters',
#        'jurisdiction_reporting_code', 'jurisdiction_reporting_requirement',
#        'committee_category', 'political_committee_type', 'bonafide_committee',
#        'bonafide_type', 'position', 'party_code', 'party', 'election_date',
#        'reporting_option', 'active_candidate', 'on_primary_election_ballot',
#        'on_general_election_ballot', 'primary_election_status',
#        'general_election_status', 'election_status', 'exempt_nonexempt',
#        'ballot_committee', 'ballot_proposal_count', 'ballot_number',
#        'ballot_title', 'for_or_against', 'ballot_proposal_detail', 'other_pac',
#        'treasurer_address', 'treasurer_city', 'treasurer_state',
#        'treasurer_zip', 'treasurer_phone', 'contributions_amount',
#        'carryforward_amount', 'expenditures_amount', 'loans_amount',
#        'pledges_amount', 'debts_amount', 'independent_expenditures_for_amount',
#        'independent_expenditures_against_amount', 'url', 'committee_id',
#        'person_id', 'candidacy_id', 'fund_id', 'legislative_district',
#        'treasurer_name', 'pac_type', 'continuing', 'updated_at',
#        'total_financial_activity', 'contribution_expenditure_ratio',
#        'is_active', 'year', 'month', 'quarter', 'contribution_category',
#        'region'],
#       dtype='object')

# %%
df_new.committee_county.unique()
# Out:
# array(['CLALLAM', nan, 'KING', 'THURSTON', 'Various', 'PACIFIC', 'KITSAP',
#        'COWLITZ', 'BENTON', 'WHITMAN', 'SNOHOMISH', 'YAKIMA', 'WHATCOM',
#        'CHELAN', 'STEVENS', 'MASON', 'PIERCE', 'ASOTIN', 'CLARK',
#        'OKANOGAN', 'LEWIS', 'KITTITAS', 'GRANT', 'SPOKANE', 'ISLAND',
#        'ADAMS', 'SKAMANIA', 'WALLA WALLA', 'FERRY', 'JEFFERSON', 'SKAGIT',
#        'GRAYS HARBOR', 'KLICKITAT', 'WAHKIAKUM', 'SAN JUAN', 'LINCOLN',
#        'PEND OREILLE', 'FRANKLIN', 'DOUGLAS', 'COLUMBIA', 'GARFIELD'],
#       dtype=object)

# %%
df_new.committee_state.unique()
# Out:
# array(['WA', nan, 'DC', 'Washington', 'Wa', 'C3 State Report', 'OR', 'wa',
#        'w', 'MD', 'NY', 'MN', 'WASHINGTON', 'VA', 'United States',
#        'WA - Washington', 'United States (+1)', 'W.a', 'CA', 'TX', 'NE',
#        'TN', 'US', 'WASHINGTON (WA)', 'ID', 'KS', 'NJ', 'OH', 'VT', 'IL',
#        'MO', 'WA.', '56', 'washington', '68', 'WY', 'Arizona',
#        'WA - WASHINGTON', 'USA', 'United States (1)', 'King', 'WA 98145',
#        'Select A County', 'Washington (WA)', 'Wa.', 'WAStates (1)',
#        'Washingon', 'SC', 'Waahington', 'id_495', 'Grant', 'Home',
#        'Washington state', 'Walla', '4426', 'Clark', '48', '47',
#        'Washihgton', 'WA Washington', 'Franklin', 'WASINGTON', 'wa.',
#        'Stevens', 'Wash', 'Skamania', 'Washinton', 'Washington State',
#        'Washinhton', 'US-WA', 'Washington(WA)', 'WA`', 'WAq', 'W',
#        'string:WA', '700', 'Washing', 'Snohomish', '3462',
#        '9227f6f4-cf63-e411-8d8b-005056ba7b6d', 'KING', 'Lewis',
#        '-- select state --', 'WaWashington'], dtype=object)

# %%
df_new[df_new['committee_state']=='Select A County'][[ 'committee_acronym',
       'committee_address', 'committee_city', 'committee_county',
       'committee_state', 'committee_zip', 'committee_email',
       'candidate_email','contributions_amount']]
# Out:
#       committee_acronym    committee_address committee_city committee_county  \
# 20658               NaN  3004 island view ct     gig harbor           PIERCE
# 49153               NaN    402 N CHESTNUT ST     ELLENSBURG         KITTITAS
#
#        committee_state committee_zip       committee_email  \
# 20658  Select A County         98335  abersolds@psd401.net
# 49153  Select A County         98926   ludlummeg@gmail.com
#
#             candidate_email  contributions_amount
# 20658  abersolds@psd401.net                   NaN
# 49153   ludlummeg@gmail.com                   NaN

# %%
def create_dashboard_views(df):
    """
    Create comprehensive views for all four dashboards
    """
    views = {}

    # OVERVIEW DASHBOARD VIEWS
    views['overview_kpis'] = df.groupby(['year', 'month']).agg({
        'contributions_amount': 'sum',
        'expenditures_amount': 'sum',
        'committee_id': 'nunique',
        'is_active': 'sum'
    }).reset_index()

    views['overview_trends'] = df.groupby(['year', 'month', 'party']).agg({
        'contributions_amount': 'sum',
        'expenditures_amount': 'sum',
        'committee_id': 'count'
    }).reset_index()

    # CONTRIBUTIONS DASHBOARD VIEWS
    views['contribution_analysis'] = df.groupby(['committee_county', 'year', 'month']).agg({
        'contributions_amount': 'sum',
        'contribution_category': lambda x: x.value_counts().to_dict(),
        'committee_id': 'nunique'
    }).reset_index()

    views['party_contributions'] = df.groupby(['party', 'year', 'month']).agg({
        'contributions_amount': 'sum',
        'committee_id': 'nunique'
    }).reset_index()

    # GEOGRAPHIC DASHBOARD VIEWS
    views['geographic_summary'] = df.groupby(['committee_county', 'region']).agg({
        'contributions_amount': 'sum',
        'expenditures_amount': 'sum',
        'committee_id': 'nunique',
        'is_active': 'sum',
        'party': lambda x: x.value_counts().to_dict()
    }).reset_index()

    views['county_trends'] = df.groupby(['committee_county', 'year', 'month']).agg({
        'contributions_amount': 'sum',
        'expenditures_amount': 'sum'
    }).reset_index()

    # COMMITTEE DASHBOARD VIEWS
    views['committee_performance'] = df.groupby(['committee_id', 'committee_category', 'party']).agg({
        'contributions_amount': 'sum',
        'expenditures_amount': 'sum',
        'is_active': 'max',
        'committee_county': 'first'
    }).reset_index()

    views['committee_trends'] = df.groupby(['committee_category', 'year', 'month']).agg({
        'contributions_amount': 'sum',
        'committee_id': 'nunique'
    }).reset_index()

    return views

# %%
df_new[df_new['committee_state']=='-- select state --'][[ 'committee_acronym',
       'committee_address', 'committee_city', 'committee_county',
       'committee_state', 'committee_zip', 'committee_email',
       'candidate_email','contributions_amount']]
# Out:
#       committee_acronym    committee_address committee_city committee_county  \
# 51611               NaN  11670 River Bend Dr    Leavenworth           CHELAN
#
#           committee_state committee_zip   committee_email   candidate_email  \
# 51611  -- select state --         98826  goehner@live.com  goehner@live.com
#
#        contributions_amount
# 51611                   NaN

# %%
df_new[df_new['committee_state']=='4426'][[ 'committee_acronym',
       'committee_address', 'committee_city', 'committee_county',
       'committee_state', 'committee_zip', 'committee_email',
       'candidate_email','contributions_amount']]
# Out:
#       committee_acronym committee_address committee_city committee_county  \
# 42217               NaN  18903 SE 44th Ct       Issaquah             KING
#
#       committee_state committee_zip        committee_email  \
# 42217            4426         98027  tim.flood@hotmail.com
#
#              candidate_email  contributions_amount
# 42217  tim.flood@hotmail.com                   NaN

# %%
df_new[df_new['committee_state']=='C3 STATE REPORT'][[ 'committee_acronym',
       'committee_address', 'committee_city', 'committee_county',
       'committee_state', 'committee_zip', 'committee_email',
       'candidate_email','contributions_amount']]
# Out:
# Empty DataFrame
# Columns: [committee_acronym, committee_address, committee_city, committee_county, committee_state, committee_zip, committee_email, candidate_email, contributions_amount]
# Index: []

# %%
df_new[df_new['committee_id'] == 1][[ 'committee_acronym',
       'committee_address', 'committee_city', 'committee_county',
       'committee_state', 'committee_zip', 'committee_email',
       'candidate_email','contributions_amount']]
# Out:
#      committee_acronym committee_address committee_city committee_county  \
# 4582               NaN       PO BOX 4187        SEATTLE              NaN
# 4589               NaN       PO BOX 4187        SEATTLE              NaN
# 4591               NaN       PO BOX 4187        SEATTLE              NaN
# 4595               NaN       PO BOX 4187        SEATTLE              NaN
# 4597               NaN       PO BOX 4187        SEATTLE              NaN
# 4602               NaN       PO BOX 4187        SEATTLE              NaN
# 4605               NaN       PO BOX 4187        SEATTLE              NaN
#
#      committee_state committee_zip                  committee_email  \
# 4582              WA         98194  COMPLIANCE@BLUEWAVEPOLITICS.COM
# 4589              WA         98194  COMPLIANCE@BLUEWAVEPOLITICS.COM
# 4591              WA         98194  COMPLIANCE@BLUEWAVEPOLITICS.COM
# 4595              WA         98194  COMPLIANCE@BLUEWAVEPOLITICS.COM
# 4597              WA         98194  COMPLIANCE@BLUEWAVEPOLITICS.COM
# 4602              WA         98194  COMPLIANCE@BLUEWAVEPOLITICS.COM
# 4605              WA         98194  COMPLIANCE@BLUEWAVEPOLITICS.COM
#
#      candidate_email  contributions_amount
# 4582             NaN            5548232.39
# 4589             NaN               1301.71
# 4591             NaN                   NaN
# 4595             NaN                   NaN
# 4597             NaN                   NaN
# 4602             NaN                   NaN
# 4605             NaN                   NaN

# %%
df_new[df_new.duplicated(subset=['committee_id'])][[ 'committee_acronym',
       'committee_address', 'committee_city', 'committee_county',
       'committee_state', 'committee_zip', 'committee_email',
       'candidate_email','contributions_amount']]
# Out:
#       committee_acronym          committee_address committee_city  \
# 2                   NaN  620 SE 168th Avenue, N-55      VANCOUVER
# 4                   NaN  620 SE 168th Avenue, N-55      VANCOUVER
# 7                   NaN                PO BOX 2595           YELM
# 8                   NaN                PO BOX 2595           YELM
# 9                   NaN                PO BOX 2595           YELM
# ...                 ...                        ...            ...
# 35999               NaN                        NaN            NaN
# 36121               NaN                        NaN            NaN
# 36147               NaN                        NaN            NaN
# 48145               NaN    7621 Steamboat Is Rd NW        Olympia
# 50011               NaN     830 SE Birch Ave Apt A  College Place
#
#       committee_county committee_state committee_zip  \
# 2                  NaN              WA    98684-8428
# 4                  NaN              WA    98684-8428
# 7                  NaN              WA         98597
# 8                  NaN              WA         98597
# 9                  NaN              WA         98597
# ...                ...             ...           ...
# 35999          SPOKANE             NaN           NaN
# 36121           YAKIMA             NaN           NaN
# 36147          STEVENS             NaN           NaN
# 48145         THURSTON              Wa         98502
# 50011      WALLA WALLA              WA         99324
#
#                  committee_email            candidate_email  \
# 2          LARRYDEV1@OUTLOOK.COM                        NaN
# 4          LARRYDEV1@OUTLOOK.COM                        NaN
# 7              SMKMMBERG@MSN.COM                        NaN
# 8              SMKMMBERG@MSN.COM                        NaN
# 9              SMKMMBERG@MSN.COM                        NaN
# ...                          ...                        ...
# 35999                        NaN                        NaN
# 36121                        NaN                        NaN
# 36147                        NaN                        NaN
# 48145      osterbergjf@gmail.com      willameen@comcast.net
# 50011  jerry.bobbitt@charter.net  jerry.bobbitt@charter.net
#
#        contributions_amount
# 2                  32805.76
# 4                      0.00
# 7                       NaN
# 8                       NaN
# 9                       NaN
# ...                     ...
# 35999                   NaN
# 36121                   NaN
# 36147                   NaN
# 48145                   NaN
# 50011                   NaN
#
# [20936 rows x 9 columns]

# %%
df_new.shape
# Out:
# (52266, 76)

# %%
df_new[df_new.contributions_amount.isnull()][[ 'committee_acronym',
       'committee_address', 'committee_city', 'committee_county',
       'committee_state', 'committee_zip', 'committee_email',
       'candidate_email','contributions_amount']]
# Out:
#       committee_acronym        committee_address committee_city  \
# 3                   NaN         6710 188th St SE      Snohomish
# 5                   NaN    4444 44TH AVE SW #405        SEATTLE
# 6                   NaN              PO BOX 2595           YELM
# 7                   NaN              PO BOX 2595           YELM
# 8                   NaN              PO BOX 2595           YELM
# ...                 ...                      ...            ...
# 52250               NaN                PO Box 74         Curlew
# 52254               DCT         General delivery        Olympia
# 52255               NaN             PO Box 12066        Seattle
# 52262               NaN  17806 111TH STREET CT E    BONNEY LAKE
# 52264             MASCJ        208 W 9TH SUITE 5     ELLENSBURG
#
#       committee_county  committee_state committee_zip  \
# 3                  NaN               WA         98296
# 5                  NaN              NaN         98116
# 6                  NaN               WA         98597
# 7                  NaN               WA         98597
# 8                  NaN               WA         98597
# ...                ...              ...           ...
# 52250            FERRY               WA         99118
# 52254              NaN               Wa         98502
# 52255             KING               WA         98102
# 52262           PIERCE               WA         98391
# 52264         KITTITAS  WASHINGTON (WA)         98926
#
#                     committee_email                      candidate_email  \
# 3            Suemagoo3802@yahoo.com                                  NaN
# 5                               NaN                                  NaN
# 6                 SMKMMBERG@MSN.COM                                  NaN
# 7                 SMKMMBERG@MSN.COM                                  NaN
# 8                 SMKMMBERG@MSN.COM                                  NaN
# ...                             ...                                  ...
# 52250     teresa@vulcanmountain.com            teresa@vulcanmountain.com
# 52254  toliverforgovernor@proton.me       desireetoliverforoly@gmail.com
# 52255             wise.julie@me.com                    wise.julie@me.com
# 52262       JUSTINEVANS78@GMAIL.COM                                  NaN
# 52264      mark@bivensandwilson.com  margiealumbaughforjudge@outlook.com
#
#        contributions_amount
# 3                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# ...                     ...
# 52250                   NaN
# 52254                   NaN
# 52255                   NaN
# 52262                   NaN
# 52264                   NaN
#
# [30111 rows x 9 columns]

# %%
df_camp_clean.shape
# Out:
# (51203, 84)

# %%
 df_new_clean1[(df_new_clean1.committee_county.isnull()) and (~df_new_clean1.committee_zip.isnull())][[ 'committee_acronym',
                                                         'committee_address', 'committee_city', 'committee_county',
                                                          'committee_state', 'committee_zip', 'committee_email',
                                                          'candidate_email','contributions_amount']]
# Out:
#       committee_acronym               committee_address committee_city  \
# 1                   NaN       620 SE 168th Avenue, N-55      VANCOUVER
# 2                   NaN       620 SE 168th Avenue, N-55      VANCOUVER
# 4                   NaN       620 SE 168th Avenue, N-55      VANCOUVER
# 13                  NaN       620 SE 168th Avenue, N-55      VANCOUVER
# 14                  NaN       620 SE 168th Avenue, N-55      VANCOUVER
# ...                 ...                             ...            ...
# 51507               NaN                    PO Box 22169        Seattle
# 51580               NaN  108 south State street apt 109        Spokane
# 51592               NaN                   P.O. Box 6182      Kennewick
# 52198               NaN                    PO Box 61856      Vancouver
# 52243               NaN                    PO Box 21961        Seattle
#
#       committee_county committee_state committee_zip  \
# 1                  NaN              WA    98684-8428
# 2                  NaN              WA    98684-8428
# 4                  NaN              WA    98684-8428
# 13                 NaN              WA    98684-8428
# 14                 NaN              WA    98684-8428
# ...                ...             ...           ...
# 51507              NaN              WA         98122
# 51580              NaN      Washington    99201-5130
# 51592              NaN              WA         99336
# 52198              NaN              WA    98666-1856
# 52243              NaN      Washington         98111
#
#                  committee_email            candidate_email  \
# 1          LARRYDEV1@OUTLOOK.COM                        NaN
# 2          LARRYDEV1@OUTLOOK.COM                        NaN
# 4          LARRYDEV1@OUTLOOK.COM                        NaN
# 13         LARRYDEV1@OUTLOOK.COM                        NaN
# 14         LARRYDEV1@OUTLOOK.COM                        NaN
# ...                          ...                        ...
# 51507  info@electbobferguson.com  info@electbobferguson.com
# 51580        votekriss@gmail.com        votekriss@gmail.com
# 51592   info@klippertforospi.com   info@klippertforospi.com
# 52198  bernardveljacic@gmail.com  bernardveljacic@gmail.com
# 52243        phil@seattlecfo.com        phil@seattlecfo.com
#
#        contributions_amount
# 1                    981.62
# 2                  32805.76
# 4                      0.00
# 13                 10130.00
# 14                   385.00
# ...                     ...
# 51507            1550213.12
# 51580                438.11
# 51592               8385.00
# 52198                  0.00
# 52243             257931.14
#
# [11072 rows x 9 columns]

# %%
# df_new_clean2 = df_new_clean1[(~df_new_clean1.committee_zip.isnull())]

# %%
#  df_new_clean1[(df_new_clean1.committee_county.isnull()) & (~df_new_clean1.committee_zip.isnull())][[ 'committee_acronym',
#                                                          'committee_address', 'committee_city', 'committee_county',
#                                                           'committee_state', 'committee_zip', 'committee_email',
#                                                           'candidate_email','contributions_amount']] (df_new_clean1.committee_county.isnull()) &

# %%
print(df_new_clean1.shape)
# print(df_new_clean2.shape)
# Out:
# (22155, 76)

# %%
df_new_clean2.committee_zip.unique()
# Out:
# array(['98382', '98684-8428', '99362', ..., '98666-1856', '98010-9799',
#        '98530'], dtype=object)

# %%
# # !pip install pgeocode
# import pgeocode
# import pandas as pd

# # Load your DataFrame (df_new_clean2_interim)
# # Example for creating dummy data
# # df_new_clean2_interim = pd.DataFrame({'committee_zip': ['98684-8428', '99362', '98168'], 'committee_county': [None, None, None]})

# # Initialize the nominatim object for US ZIP codes
# nomi = pgeocode.Nominatim('US')

# # Function to get the county name
# def get_county(zip_code):
#     base_zip = zip_code.split('-')[0]  # Handle ZIP+4 format
#     location = nomi.query_postal_code(base_zip)
#     if location is not None:
#         return location.county_name
#     else:
#         return None

# # Update the 'committee_county' column
# df_new_clean1_copy['committee_county'] = df_new_clean1_copy.apply(
#     lambda row: get_county(row['committee_zip']) if pd.isnull(row['committee_county']) else row['committee_county'],
#     axis=1
# )

# # Display the updated DataFrame
# print(df_new_clean2_interim)
# Out:
#                     id    filer_id filer_type              registered  \
# 0        ca-2024-93123  VANDK  382         CA  01/19/2021 12:00:00 AM
# 1            co-2011-8  17THDR 683         CO                     NaN
# 2            co-2012-8  17THDR 683         CO                     NaN
# 4            co-2013-8  17THDR 683         CO                     NaN
# 13           co-2014-8  17THDR 683         CO                     NaN
# ...                ...         ...        ...                     ...
# 52259   ca-2026-689072  TORRN--301         CA  01/12/2023 12:00:00 AM
# 52260  ca-2027-3279394  FELLF  109         CA  01/18/2024 12:00:00 AM
# 52261  ca-2024-3311816  PEREE--957         CA  05/14/2024 12:00:00 AM
# 52263  ca-2024-3296715  HOFEF  639         CA  03/28/2024 12:00:00 AM
# 52265  ca-2024-3296780  MELMJ--888         CA  04/12/2024 12:00:00 AM
#
#                      declared withdrew discontinued filing_type receipt_date  \
# 0                         NaN      NaN          NaN  Electronic   01/19/2021
# 1                         NaN      NaN          NaN  Electronic   03/30/2008
# 2                         NaN      NaN          NaN  Electronic   03/30/2008
# 4                         NaN      NaN          NaN  Electronic   03/30/2008
# 13                        NaN      NaN          NaN  Electronic   03/30/2008
# ...                       ...      ...          ...         ...          ...
# 52259                     NaN      NaN          NaN  Electronic   01/12/2023
# 52260                     NaN      NaN          NaN  Electronic   01/18/2024
# 52261  05/10/2024 12:00:00 AM      NaN          NaN  Electronic   05/14/2024
# 52263  05/09/2024 12:00:00 AM      NaN          NaN  Electronic   03/28/2024
# 52265  05/06/2024 12:00:00 AM      NaN          NaN  Electronic   04/12/2024
#
#        election_year  ...                                                url  \
# 0               2024  ...  https://apollo.pdc.wa.gov/public/registrations...
# 1               2011  ...  https://web.pdc.wa.gov/rptimg/default.aspx?doc...
# 2               2012  ...  https://web.pdc.wa.gov/rptimg/default.aspx?doc...
# 4               2013  ...  https://web.pdc.wa.gov/rptimg/default.aspx?doc...
# 13              2014  ...  https://web.pdc.wa.gov/rptimg/default.aspx?doc...
# ...              ...  ...                                                ...
# 52259           2026  ...  https://apollo.pdc.wa.gov/public/registrations...
# 52260           2027  ...  https://apollo.pdc.wa.gov/public/registrations...
# 52261           2024  ...  https://apollo.pdc.wa.gov/public/registrations...
# 52263           2024  ...  https://apollo.pdc.wa.gov/public/registrations...
# 52265           2024  ...  https://apollo.pdc.wa.gov/public/registrations...
#
#       committee_id person_id candidacy_id  fund_id legislative_district  \
# 0          26492.0   26330.0      93123.0  17290.0                 24.0
# 1              8.0   32738.0          NaN  10871.0                  NaN
# 2              8.0   32738.0          NaN   9631.0                  NaN
# 4              8.0   32738.0          NaN   8641.0                  NaN
# 13             8.0   32738.0          NaN   7430.0                  NaN
# ...            ...       ...          ...      ...                  ...
# 52259      31619.0   31599.0     689072.0  19881.0                 16.0
# 52260      35502.0    1180.0    3279394.0  23762.0                  NaN
# 52261      36561.0   46193.0    3311816.0  24360.0                 14.0
# 52263      36100.0    2816.0    3296715.0  24288.0                  NaN
# 52265      36193.0   45153.0    3296780.0  24027.0                 42.0
#
#        treasurer_name   pac_type continuing              updated_at
# 0       JASON BENNETT  candidate        NaN  08/26/2024 07:09:08 PM
# 1       LARRY DEVRIES   bonafide       True  09/19/2024 10:32:09 AM
# 2       LARRY DEVRIES   bonafide       True  09/19/2024 10:32:09 AM
# 4       LARRY DEVRIES   bonafide       True  09/19/2024 10:32:09 AM
# 13      LARRY DEVRIES   bonafide       True  09/19/2024 10:32:09 AM
# ...               ...        ...        ...                     ...
# 52259   Jason Michaud  candidate        NaN  09/04/2024 07:45:14 PM
# 52260         Andy Lo  candidate        NaN  09/07/2024 08:03:56 AM
# 52261     Eddie Perez  candidate        NaN  08/29/2024 07:03:22 AM
# 52263  Krystal Patton  candidate        NaN  08/29/2024 07:03:25 AM
# 52265         Andy Lo  candidate        NaN  09/12/2024 07:19:08 AM
#
# [22155 rows x 76 columns]

# %%
import pgeocode
import pandas as pd

# Initialize the nominatim object for US ZIP codes
nomi = pgeocode.Nominatim('US')

# Function to get the county name
def get_county(zip_code):
    try:
        # Handle ZIP+4 format by splitting and using base ZIP
        base_zip = str(zip_code).split('-')[0]
        location = nomi.query_postal_code(base_zip)
        if location is not None and pd.notnull(location.county_name):
            return location.county_name
        else:
            return None
    except Exception as e:
        return None

# Apply the function to the unmapped rows
df_new_clean1_copy['committee_county'] = df_new_clean1_copy.apply(
    lambda row: get_county(row['committee_zip']) if pd.isnull(row['committee_county']) else row['committee_county'],
    axis=1
)

# Check rows that still have missing counties
unmapped_zips = df_new_clean1_copy[df_new_clean1_copy['committee_county'].isnull()]

# Log unmapped ZIP codes for manual inspection
print("Unmapped ZIP codes:")
print(unmapped_zips['committee_zip'].unique())

# Optionally, save the remaining unmapped entries to a CSV for manual review
unmapped_zips.to_csv('unmapped_zips.csv', index=False)

# Save the updated DataFrame to a CSV
df_new_clean1_copy.to_csv('updated_committee_data_with_all_counties.csv', index=False)

# Print the updated DataFrame
print("Updated DataFrame with county mapping:")
df_new_clean1_copy
# Out:
# Unmapped ZIP codes:
# ['980933522' '980023384' '980312091' '984990556' '980645882' '982610296'
#  '980347501' '98697' '981991011' '992233013' '986470321' '980460365'
#  '988071824' '988020212' '981390513' '983601015' '982751182' '981113854'
#  '993501189' '983330243' '980121391' '982720764' '38102' '9206-3601'
#  '980579798' '980091153' '992239998' '207722687' '72883' '983921024'
#  '985128108' '984970164' '980720981' '981445407' '992040086' '992248223'
#  '98205' '980209516' '981212411' '983722000' '985700151' '980401192'
#  '985070658' '985076328' '983870875' '986728908' '983706233' '986872382'
#  '981341914' '980365719' '981130149' '980090728' '981056191' '980830817'
#  '985699371' '984075810' '981554002' '989263325' '982502431' '981113481'
#  '985077704' '984112393' '981011300' '981334419' '980710124' '981102648'
#  '980923700' '993527601' '993620023' '981341823' '985093131' '982062612'
#  '989072129' '983370204' '992141716' '980588989' '981034128' '982214183'
#  '982210653' '982293816' '982270812' '984011743' '982931323' '988075087'
#  '982239813' '985889612' '983371402' '981684509' '982820135' '992162096'
#  '984674912' '986660764' '982827279' '985070125' '980634981' '984485227'
#  '984484227' '984480454' '985013967' '980589212' '982252655' '982589083'
#  '981112323' '981660127' '981480188' '985061002' '981113984' '100201099'
#  '983689483' '993364417' '980341954' '981246971' '980338740' '981552436'
#  '982589468' '980337932' '981113681' '980404915' '985929786' '990210854'
#  '982269732' '982254212' '984021474' '980062205' '983916304' '981112282'
#  '988072065' '980266434' '985165535' '988550612' '981111115' '988550652'
#  '982770345' '980362011' '981253801' '985018212' '98149' '982284315'
#  '981113252' '982360095' '986711227' '982360622' '981094355' '983833173'
#  '983940155' '980201261' '983714409' '980524444' '980555033' '984641488'
#  '992033536' '980633786' '982282354' '980274806' '981112264' '981989116'
#  '992100251' '980779357' '984010735' '986660211' '981111727' '981681032'
#  '982350337' '90836' '992010704' '992010668' '992204725' '984443235'
#  '981094512' '983390003' '992120391' '985201014' '988270004' '989267303'
#  '985012251' '981342438' '985077591' '981114332' '981259401' '983541843'
#  '99288' '980312022' '982391111' '981113768' '980362384' '992043744'
#  '982043877' '981113707' '980730291' '988161470' '985077395' '985081956'
#  '985070264' '980732631' '992122506' '98285' '983900816' '980337637'
#  '98018' '980035201' '981094599' '98301' '992101663' '990220751'
#  '981113954' '985077485' '992021174' '985013565' '992099447' '983880010'
#  '981114735' '981112747' '989248644' '981041925' '986323701' '980201265'
#  '984176948' '981110385' '985070522' '985071636' '981170470' '981130805'
#  '991112734' '985072375' '985071253' '983460411' '980401572' '981112405'
#  '985125518' '985076126']
# Updated DataFrame with county mapping:
#                     id    filer_id filer_type              registered  \
# 0        ca-2024-93123  VANDK  382         CA  01/19/2021 12:00:00 AM
# 1            co-2011-8  17THDR 683         CO                     NaN
# 2            co-2012-8  17THDR 683         CO                     NaN
# 4            co-2013-8  17THDR 683         CO                     NaN
# 13           co-2014-8  17THDR 683         CO                     NaN
# ...                ...         ...        ...                     ...
# 52259   ca-2026-689072  TORRN--301         CA  01/12/2023 12:00:00 AM
# 52260  ca-2027-3279394  FELLF  109         CA  01/18/2024 12:00:00 AM
# 52261  ca-2024-3311816  PEREE--957         CA  05/14/2024 12:00:00 AM
# 52263  ca-2024-3296715  HOFEF  639         CA  03/28/2024 12:00:00 AM
# 52265  ca-2024-3296780  MELMJ--888         CA  04/12/2024 12:00:00 AM
#
#                      declared withdrew discontinued filing_type receipt_date  \
# 0                         NaN      NaN          NaN  Electronic   01/19/2021
# 1                         NaN      NaN          NaN  Electronic   03/30/2008
# 2                         NaN      NaN          NaN  Electronic   03/30/2008
# 4                         NaN      NaN          NaN  Electronic   03/30/2008
# 13                        NaN      NaN          NaN  Electronic   03/30/2008
# ...                       ...      ...          ...         ...          ...
# 52259                     NaN      NaN          NaN  Electronic   01/12/2023
# 52260                     NaN      NaN          NaN  Electronic   01/18/2024
# 52261  05/10/2024 12:00:00 AM      NaN          NaN  Electronic   05/14/2024
# 52263  05/09/2024 12:00:00 AM      NaN          NaN  Electronic   03/28/2024
# 52265  05/06/2024 12:00:00 AM      NaN          NaN  Electronic   04/12/2024
#
#        election_year  ...                                                url  \
# 0               2024  ...  https://apollo.pdc.wa.gov/public/registrations...
# 1               2011  ...  https://web.pdc.wa.gov/rptimg/default.aspx?doc...
# 2               2012  ...  https://web.pdc.wa.gov/rptimg/default.aspx?doc...
# 4               2013  ...  https://web.pdc.wa.gov/rptimg/default.aspx?doc...
# 13              2014  ...  https://web.pdc.wa.gov/rptimg/default.aspx?doc...
# ...              ...  ...                                                ...
# 52259           2026  ...  https://apollo.pdc.wa.gov/public/registrations...
# 52260           2027  ...  https://apollo.pdc.wa.gov/public/registrations...
# 52261           2024  ...  https://apollo.pdc.wa.gov/public/registrations...
# 52263           2024  ...  https://apollo.pdc.wa.gov/public/registrations...
# 52265           2024  ...  https://apollo.pdc.wa.gov/public/registrations...
#
#       committee_id person_id candidacy_id  fund_id legislative_district  \
# 0          26492.0   26330.0      93123.0  17290.0                 24.0
# 1              8.0   32738.0          NaN  10871.0                  NaN
# 2              8.0   32738.0          NaN   9631.0                  NaN
# 4              8.0   32738.0          NaN   8641.0                  NaN
# 13             8.0   32738.0          NaN   7430.0                  NaN
# ...            ...       ...          ...      ...                  ...
# 52259      31619.0   31599.0     689072.0  19881.0                 16.0
# 52260      35502.0    1180.0    3279394.0  23762.0                  NaN
# 52261      36561.0   46193.0    3311816.0  24360.0                 14.0
# 52263      36100.0    2816.0    3296715.0  24288.0                  NaN
# 52265      36193.0   45153.0    3296780.0  24027.0                 42.0
#
#        treasurer_name   pac_type continuing              updated_at
# 0       JASON BENNETT  candidate        NaN  08/26/2024 07:09:08 PM
# 1       LARRY DEVRIES   bonafide       True  09/19/2024 10:32:09 AM
# 2       LARRY DEVRIES   bonafide       True  09/19/2024 10:32:09 AM
# 4       LARRY DEVRIES   bonafide       True  09/19/2024 10:32:09 AM
# 13      LARRY DEVRIES   bonafide       True  09/19/2024 10:32:09 AM
# ...               ...        ...        ...                     ...
# 52259   Jason Michaud  candidate        NaN  09/04/2024 07:45:14 PM
# 52260         Andy Lo  candidate        NaN  09/07/2024 08:03:56 AM
# 52261     Eddie Perez  candidate        NaN  08/29/2024 07:03:22 AM
# 52263  Krystal Patton  candidate        NaN  08/29/2024 07:03:25 AM
# 52265         Andy Lo  candidate        NaN  09/12/2024 07:19:08 AM
#
# [22155 rows x 76 columns]

# %%
import pgeocode
import pandas as pd

# Initialize the nominatim object for US ZIP codes
nomi = pgeocode.Nominatim('US')

# Function to format ZIP codes into ZIP+4 if necessary
def format_zip(zip_code):
    zip_str = str(zip_code)
    if len(zip_str) == 9 and zip_str.isdigit():  # If it's 9 digits and numeric
        return zip_str[:5] + '-' + zip_str[5:]
    elif len(zip_str) == 5 and zip_str.isdigit():  # If it's 5 digits
        return zip_str
    else:
        return zip_str  # Leave other formats unchanged

# Function to get the county name
def get_county(zip_code):
    try:
        formatted_zip = format_zip(zip_code)  # Ensure proper formatting
        base_zip = formatted_zip.split('-')[0]  # Use only the first 5 digits for lookup
        location = nomi.query_postal_code(base_zip)
        if location is not None and pd.notnull(location.county_name):
            return location.county_name
        else:
            return None
    except Exception as e:
        return None

# Apply formatting to ZIP codes and update the county mapping
df_new_clean1_copy['committee_zip'] = df_new_clean1_copy['committee_zip'].apply(format_zip)

# Update the 'committee_county' column using the formatted ZIP codes
df_new_clean1_copy['committee_county'] = df_new_clean1_copy.apply(
    lambda row: get_county(row['committee_zip']) if pd.isnull(row['committee_county']) else row['committee_county'],
    axis=1
)

# Check rows that still have missing counties
unmapped_zips = df_new_clean1_copy[df_new_clean1_copy['committee_county'].isnull()]

# Log unmapped ZIP codes for manual inspection
print("Unmapped ZIP codes:")
print(unmapped_zips['committee_zip'].unique())
# Out:
# Unmapped ZIP codes:
# ['98697' '38102' '9206-3601' '72883' '98205' '98149' '90836' '99288'
#  '98285' '98018' '98301' '98924-8644']

# %%
df_new_clean1_copy[df_new_clean1_copy['committee_county'].isnull()][[ 'committee_acronym','committee_address', 'committee_city', 'committee_county',
                    'committee_state', 'committee_zip', 'committee_email',
                     'candidate_email','contributions_amount']]
# Out:
#        committee_acronym              committee_address  committee_city  \
# 416    Citizens For Yelm                    PO BOX 1537            Yelm
# 1635                 NaN         942 S Shady Grove Road         Memphis
# 1636                 NaN         942 S Shady Grove Road         Memphis
# 1637                 NaN         942 S Shady Grove Road         Memphis
# 1638                 NaN         942 S Shady Grove Road         Memphis
# 1640                 NaN         942 S Shady Grove Road         Memphis
# 1641                 NaN         942 S Shady Grove Road         Memphis
# 2392                 NaN          9116 E. Sprague, #118  Spokane Valley
# 2865                 NaN         942 S Shady Grove Road         Memphis
# 2866                 NaN         942 S Shady Grove Road         Memphis
# 2867                 NaN         942 S Shady Grove Road         Memphis
# 3040                 NaN            1012 E. Hemlock St.            Kent
# 3738                 NaN       10515 20TH ST SE STE 100         EVERETT
# 4658                 NaN            1012 E. Hemlock St.            Kent
# 9608                 NaN            1012 E. Hemlock St.            Kent
# 9609                 NaN            1012 E. Hemlock St.            Kent
# 9610                 NaN            1012 E. Hemlock St.            Kent
# 9611                 NaN            1012 E. Hemlock St.            Kent
# 9612                 NaN            1012 E. Hemlock St.            Kent
# 9613                 NaN            1012 E. Hemlock St.            Kent
# 9616                 NaN            1012 E. Hemlock St.            Kent
# 9617                 NaN            1012 E. Hemlock St.            Kent
# 9618                 NaN            1012 E. Hemlock St.            Kent
# 9619                 NaN            1012 E. Hemlock St.            Kent
# 9620                 NaN            1012 E. Hemlock St.            Kent
# 9621                 NaN            1012 E. Hemlock St.            Kent
# 9622                 NaN            1012 E. Hemlock St.            Kent
# 9623                 NaN            1012 E. Hemlock St.            Kent
# 11718                NaN                  P.O. BOX 4382         SEATTLE
# 12497                NaN       10515 20TH ST SE STE 100         EVERETT
# 13473            SnoCoLP                    PO BOX 2575        LYNNWOOD
# 15003                NaN                   PO BOX 18250         SPOKANE
# 17401                NaN  5400 HARBOUR POINTE BLVD J101        MUKILTEO
# 17467                NaN              7416 NE 169TH ST.         KENMORE
# 20537                NaN                  P.O. BOX 2371          YAKIMA
# 28351                NaN              32456 138TH ST SE          SULTAN
#
#       committee_county committee_state committee_zip  \
# 416               None              WA         98697
# 1635              None              TN         38102
# 1636              None              TN         38102
# 1637              None              TN         38102
# 1638              None              TN         38102
# 1640              None              TN         38102
# 1641              None              TN         38102
# 2392              None              WA     9206-3601
# 2865              None              TN         38102
# 2866              None              TN         38102
# 2867              None              TN         38102
# 3040              None              WA         72883
# 3738              None             NaN         98205
# 4658              None              WA         72883
# 9608              None              WA         72883
# 9609              None              WA         72883
# 9610              None              WA         72883
# 9611              None              WA         72883
# 9612              None              WA         72883
# 9613              None              WA         72883
# 9616              None              WA         72883
# 9617              None              WA         72883
# 9618              None              WA         72883
# 9619              None              WA         72883
# 9620              None              WA         72883
# 9621              None              WA         72883
# 9622              None              WA         72883
# 9623              None              WA         72883
# 11718             None              WA         98149
# 12497             None             NaN         98205
# 13473             None              WA         90836
# 15003             None             NaN         99288
# 17401             None              WA         98285
# 17467             None              WA         98018
# 20537             None              WA         98301
# 28351             None             NaN    98924-8644
#
#                                 committee_email        candidate_email  \
# 416              citizens4yelmschools@gmail.com                    NaN
# 1635                         Fedexpac@fedex.com                    NaN
# 1636                         Fedexpac@fedex.com                    NaN
# 1637                         Fedexpac@fedex.com                    NaN
# 1638                         Fedexpac@fedex.com                    NaN
# 1640                         Fedexpac@fedex.com                    NaN
# 1641                         Fedexpac@fedex.com                    NaN
# 2392                         matt@mchawkins.org       matt@HnA-Cap.com
# 2865                         Fedexpac@fedex.com                    NaN
# 2866                         Fedexpac@fedex.com                    NaN
# 2867                         Fedexpac@fedex.com                    NaN
# 3040                         tj592004@yahoo.com                    NaN
# 3738   COALITIONFORQUALITYCOMMUNITIES@YAHOO.COM                    NaN
# 4658                         tj592004@yahoo.com                    NaN
# 9608                         tj592004@yahoo.com                    NaN
# 9609                         tj592004@yahoo.com                    NaN
# 9610                         tj592004@yahoo.com                    NaN
# 9611                         tj592004@yahoo.com                    NaN
# 9612                         tj592004@yahoo.com                    NaN
# 9613                         tj592004@yahoo.com                    NaN
# 9616                         tj592004@yahoo.com                    NaN
# 9617                         tj592004@yahoo.com                    NaN
# 9618                         tj592004@yahoo.com                    NaN
# 9619                         tj592004@yahoo.com                    NaN
# 9620                         tj592004@yahoo.com                    NaN
# 9621                         tj592004@yahoo.com                    NaN
# 9622                         tj592004@yahoo.com                    NaN
# 9623                         tj592004@yahoo.com                    NaN
# 11718             PEOPLEFORSARANELSON@GMAIL.COM                    NaN
# 12497         QUALITYCOMMUNITIESPAC@HOTMAIL.COM                    NaN
# 13473                         SNOCOLP@GMAIL.COM                    NaN
# 15003                       JAKATAK@COMCAST.NET                    NaN
# 17401                         INFO@YESONEMS.ORG                    NaN
# 17467            YESWALKWAYSWATERWAYS@GMAIL.COM                    NaN
# 20537                     DOUGFEDERSPIEL@ME.COM  dougfederspiel@me.com
# 28351                CAMPAIGN@IMAGINELIBERTY.US  delsorgen@comcast.net
#
#        contributions_amount
# 416                14222.36
# 1635                   0.00
# 1636                   0.00
# 1637                   0.00
# 1638                   0.00
# 1640                   0.00
# 1641                   0.00
# 2392               14015.71
# 2865                   0.00
# 2866                   0.00
# 2867                   0.00
# 3040               27280.16
# 3738               92257.35
# 4658               23187.40
# 9608               32474.96
# 9609               26757.86
# 9610               36539.40
# 9611               34312.40
# 9612               16665.00
# 9613               19108.00
# 9616               17687.50
# 9617               17917.50
# 9618               22092.00
# 9619               20324.00
# 9620               23538.00
# 9621               25646.00
# 9622               20510.00
# 9623               22522.00
# 11718             121880.12
# 12497              91036.00
# 13473                788.44
# 15003             802265.62
# 17401                  8.99
# 17467               7919.46
# 20537               2202.41
# 28351               2469.00

# %%
from geopy.geocoders import Nominatim
import pandas as pd

# Initialize the geolocator
geolocator = Nominatim(user_agent="county_mapper")

# Function to get the county name using city and state
def get_county_from_city_state(row):
    try:
        if pd.isnull(row['committee_county']) and pd.notnull(row['committee_city']) and pd.notnull(row['committee_state']):
            location = geolocator.geocode(f"{row['committee_city']}, {row['committee_state']}, USA")
            if location and location.raw.get('address'):
                return location.raw['address'].get('county')
        return row['committee_county']  # Return existing county if not null
    except Exception as e:
        return row['committee_county']  # If any issue occurs, leave it as is

# Apply the function to fill missing committee_county using city and state
df_new_clean1_copy['committee_county'] = df_new_clean1_copy.apply(get_county_from_city_state, axis=1)

# Check rows that still have missing counties
unmapped_rows = df_new_clean1_copy[df_new_clean1_copy['committee_county'].isnull()]

# Log unmapped rows for manual inspection
print("Remaining unmapped rows:")
# Out:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=YAKIMA%2C+WA%2C+USA&format=json&limit=1
# Remaining unmapped rows:
#                     id    filer_id filer_type              registered  \
# 416      co-2023-37024  CITISY 597         CO                     NaN
# 1635     co-2013-35568  FEDEE  120         OS                     NaN
# 1636     co-2014-35568  FEDEE  120         OS                     NaN
# 1637     co-2015-35568  FEDEE  120         OS                     NaN
# 1638     co-2016-35568  FEDEE  120         OS                     NaN
# 1640     co-2017-35568  FEDEE  120         OS                     NaN
# 1641     co-2023-35568  FEDEE  120         OS                     NaN
# 2392   ca-2024-3305493  HAWKM--987         CA  05/08/2024 12:00:00 AM
# 2865     co-2018-35568  FEDEE  120         OS                     NaN
# 2866     co-2019-35568  FEDEE  120         OS                     NaN
# 2867     co-2020-35568  FEDEE  120         OS                     NaN
# 3040     co-2011-10288  KENTFF 035         CO                     NaN
# 3738      co-2007-3841  COALQC 291         CO                     NaN
# 4658     co-2024-10288  KENTFF 035         CO                     NaN
# 9608     co-2007-10288  KENTFF 035         CO                     NaN
# 9609     co-2008-10288  KENTFF 035         CO                     NaN
# 9610     co-2009-10288  KENTFF 035         CO                     NaN
# 9611     co-2010-10288  KENTFF 035         CO                     NaN
# 9612     co-2012-10288  KENTFF 035         CO                     NaN
# 9613     co-2013-10288  KENTFF 035         CO                     NaN
# 9616     co-2016-10288  KENTFF 035         CO                     NaN
# 9617     co-2017-10288  KENTFF 035         CO                     NaN
# 9618     co-2018-10288  KENTFF 035         CO                     NaN
# 9619     co-2019-10288  KENTFF 035         CO                     NaN
# 9620     co-2020-10288  KENTFF 035         CO                     NaN
# 9621     co-2021-10288  KENTFF 035         CO                     NaN
# 9622     co-2022-10288  KENTFF 035         CO                     NaN
# 9623     co-2023-10288  KENTFF 035         CO                     NaN
# 11718    co-2017-15057  PEOPSN 149         CO                     NaN
# 12497    co-2007-15884  QUALCP 291         CO                     NaN
# 13473    co-2017-18239  SNOHLP 043         CO                     NaN
# 15003    co-2009-20290  VOTEWM 207         CO                     NaN
# 17401    co-2018-21820  YES EM 285         CO                     NaN
# 17467    co-2016-21886  YES WW 018         CO                     NaN
# 20537     ca-2018-1973  FEDED  907         CA  02/04/2018 12:00:00 AM
# 28351    ca-2012-10622  SORGL  924         CA  11/05/2009 12:00:00 AM
#
#                      declared withdrew discontinued filing_type receipt_date  \
# 416                       NaN      NaN          NaN  Electronic   09/12/2024
# 1635                      NaN      NaN          NaN         NaN          NaN
# 1636                      NaN      NaN          NaN         NaN          NaN
# 1637                      NaN      NaN          NaN         NaN          NaN
# 1638                      NaN      NaN          NaN         NaN          NaN
# 1640                      NaN      NaN          NaN         NaN          NaN
# 1641                      NaN      NaN          NaN         NaN          NaN
# 2392   05/06/2024 12:00:00 AM      NaN          NaN  Electronic   05/08/2024
# 2865                      NaN      NaN          NaN         NaN          NaN
# 2866                      NaN      NaN          NaN         NaN          NaN
# 2867                      NaN      NaN          NaN         NaN          NaN
# 3040                      NaN      NaN          NaN  Electronic   08/10/2001
# 3738                      NaN      NaN          NaN  Electronic   07/22/2007
# 4658                      NaN      NaN          NaN  Electronic   08/10/2001
# 9608                      NaN      NaN          NaN  Electronic   08/10/2001
# 9609                      NaN      NaN          NaN  Electronic   08/10/2001
# 9610                      NaN      NaN          NaN  Electronic   08/10/2001
# 9611                      NaN      NaN          NaN  Electronic   08/10/2001
# 9612                      NaN      NaN          NaN  Electronic   08/10/2001
# 9613                      NaN      NaN          NaN  Electronic   08/10/2001
# 9616                      NaN      NaN          NaN  Electronic   08/10/2001
# 9617                      NaN      NaN          NaN  Electronic   08/10/2001
# 9618                      NaN      NaN          NaN  Electronic   08/10/2001
# 9619                      NaN      NaN          NaN  Electronic   08/10/2001
# 9620                      NaN      NaN          NaN  Electronic   08/10/2001
# 9621                      NaN      NaN          NaN  Electronic   08/10/2001
# 9622                      NaN      NaN          NaN  Electronic   08/10/2001
# 9623                      NaN      NaN          NaN  Electronic   08/10/2001
# 11718                     NaN      NaN          NaN  Electronic   06/21/2017
# 12497                     NaN      NaN          NaN  Electronic   07/22/2007
# 13473                     NaN      NaN          NaN  Electronic   03/07/2017
# 15003                     NaN      NaN          NaN  Electronic   01/06/2009
# 17401                     NaN      NaN          NaN  Electronic   05/21/2018
# 17467                     NaN      NaN          NaN  Electronic   09/04/2016
# 20537                     NaN      NaN          NaN  Electronic   02/04/2018
# 28351                     NaN      NaN          NaN  Electronic   11/05/2009
#
#        election_year  ...                                                url  \
# 416             2023  ...  https://apollo.pdc.wa.gov/public/registrations...
# 1635            2013  ...  https://www.pdc.wa.gov/political-disclosure-re...
# 1636            2014  ...  https://www.pdc.wa.gov/political-disclosure-re...
# 1637            2015  ...  https://www.pdc.wa.gov/political-disclosure-re...
# 1638            2016  ...  https://www.pdc.wa.gov/political-disclosure-re...
# 1640            2017  ...  https://www.pdc.wa.gov/political-disclosure-re...
# 1641            2023  ...  https://web.pdc.wa.gov/rptimg/default.aspx?doc...
# 2392            2024  ...  https://apollo.pdc.wa.gov/public/registrations...
# 2865            2018  ...  https://www.pdc.wa.gov/political-disclosure-re...
# 2866            2019  ...  https://www.pdc.wa.gov/political-disclosure-re...
# 2867            2020  ...  https://www.pdc.wa.gov/political-disclosure-re...
# 3040            2011  ...  https://web.pdc.wa.gov/rptimg/default.aspx?doc...
# 3738            2007  ...  https://web.pdc.wa.gov/rptimg/default.aspx?doc...
# 4658            2024  ...  https://apollo.pdc.wa.gov/public/registrations...
# 9608            2007  ...  https://web.pdc.wa.gov/rptimg/default.aspx?doc...
# 9609            2008  ...  https://web.pdc.wa.gov/rptimg/default.aspx?doc...
# 9610            2009  ...  https://web.pdc.wa.gov/rptimg/default.aspx?doc...
# 9611            2010  ...  https://web.pdc.wa.gov/rptimg/default.aspx?doc...
# 9612            2012  ...  https://web.pdc.wa.gov/rptimg/default.aspx?fil...
# 9613            2013  ...  https://web.pdc.wa.gov/rptimg/default.aspx?fil...
# 9616            2016  ...  https://web.pdc.wa.gov/rptimg/default.aspx?doc...
# 9617            2017  ...  https://web.pdc.wa.gov/rptimg/default.aspx?doc...
# 9618            2018  ...  https://web.pdc.wa.gov/rptimg/default.aspx?doc...
# 9619            2019  ...  https://web.pdc.wa.gov/rptimg/default.aspx?doc...
# 9620            2020  ...  https://web.pdc.wa.gov/rptimg/default.aspx?doc...
# 9621            2021  ...  https://web.pdc.wa.gov/rptimg/default.aspx?doc...
# 9622            2022  ...  https://apollo.pdc.wa.gov/public/registrations...
# 9623            2023  ...  https://apollo.pdc.wa.gov/public/registrations...
# 11718           2017  ...  https://web.pdc.wa.gov/rptimg/default.aspx?doc...
# 12497           2007  ...  https://web.pdc.wa.gov/rptimg/default.aspx?doc...
# 13473           2017  ...  https://web.pdc.wa.gov/rptimg/default.aspx?doc...
# 15003           2009  ...  https://web.pdc.wa.gov/rptimg/default.aspx?doc...
# 17401           2018  ...  https://web.pdc.wa.gov/rptimg/default.aspx?doc...
# 17467           2016  ...  https://web.pdc.wa.gov/rptimg/default.aspx?doc...
# 20537           2018  ...  https://web.pdc.wa.gov/rptimg/default.aspx?doc...
# 28351           2012  ...  https://web.pdc.wa.gov/rptimg/default.aspx?fil...
#
#       committee_id person_id candidacy_id  fund_id legislative_district  \
# 416        37024.0   33103.0          NaN  24589.0                  NaN
# 1635       35568.0   44283.0          NaN  22879.0                  NaN
# 1636       35568.0   44283.0          NaN  22880.0                  NaN
# 1637       35568.0   44283.0          NaN  22881.0                  NaN
# 1638       35568.0   44283.0          NaN  22883.0                  NaN
# 1640       35568.0   44283.0          NaN  22884.0                  NaN
# 1641       35568.0   44283.0          NaN  24508.0                  NaN
# 2392       36338.0   45571.0    3305493.0  24061.0                  NaN
# 2865       35568.0   44283.0          NaN  22885.0                  NaN
# 2866       35568.0   44283.0          NaN  22886.0                  NaN
# 2867       35568.0   44283.0          NaN  22882.0                  NaN
# 3040       10288.0   33559.0          NaN  11298.0                  NaN
# 3738        3841.0       NaN          NaN  15691.0                  NaN
# 4658       10288.0   33559.0          NaN  22626.0                  NaN
# 9608       10288.0   33559.0          NaN  15943.0                  NaN
# 9609       10288.0   33559.0          NaN  14803.0                  NaN
# 9610       10288.0   33559.0          NaN  13655.0                  NaN
# 9611       10288.0   33559.0          NaN  12461.0                  NaN
# 9612       10288.0   33559.0          NaN  10186.0                  NaN
# 9613       10288.0   33559.0          NaN   9075.0                  NaN
# 9616       10288.0   33559.0          NaN   5701.0                  NaN
# 9617       10288.0   33559.0          NaN   4518.0                  NaN
# 9618       10288.0   33559.0          NaN   3294.0                  NaN
# 9619       10288.0   33559.0          NaN   1999.0                  NaN
# 9620       10288.0   33559.0          NaN    747.0                  NaN
# 9621       10288.0   33559.0          NaN  17138.0                  NaN
# 9622       10288.0   33559.0          NaN  18914.0                  NaN
# 9623       10288.0   33559.0          NaN  20322.0                  NaN
# 11718      15057.0   33850.0          NaN   4751.0                  NaN
# 12497      15884.0       NaN          NaN  16178.0                  NaN
# 13473      18239.0   34089.0          NaN   4899.0                  NaN
# 15003      20290.0   34270.0          NaN  14101.0                  NaN
# 17401      21820.0   34506.0          NaN   4005.0                  NaN
# 17467      21886.0   34552.0          NaN   6383.0                  NaN
# 20537       6069.0    1784.0       1973.0   3101.0                  NaN
# 28351      18419.0    7849.0      10622.0  10596.0                  NaN
#
#            treasurer_name      pac_type continuing              updated_at
# 416        Gina Cooprider           pac       True  09/20/2024 12:07:13 PM
# 1635                  NaN  out-of-state       True  08/16/2024 03:29:14 PM
# 1636                  NaN  out-of-state       True  08/16/2024 03:29:14 PM
# 1637                  NaN  out-of-state       True  08/16/2024 03:29:14 PM
# 1638                  NaN  out-of-state       True  08/16/2024 03:29:14 PM
# 1640                  NaN  out-of-state       True  08/16/2024 03:29:14 PM
# 1641                  NaN  out-of-state       True  08/16/2024 03:29:14 PM
# 2392         Sharon Hanek     candidate        NaN  09/16/2024 07:38:09 PM
# 2865                  NaN  out-of-state       True  08/16/2024 03:29:14 PM
# 2866                  NaN  out-of-state       True  08/16/2024 03:29:14 PM
# 2867                  NaN  out-of-state       True  08/16/2024 03:29:14 PM
# 3040       Terry McCartin           pac       True  01/10/2024 10:44:59 AM
# 3738       BLAIR ANDERSON           pac       True  11/14/2020 10:10:59 AM
# 4658       Terry McCartin           pac       True  09/07/2024 11:00:38 AM
# 9608       Terry McCartin           pac       True  01/10/2024 10:44:59 AM
# 9609       Terry McCartin           pac       True  01/10/2024 10:44:59 AM
# 9610       Terry McCartin           pac       True  01/10/2024 10:44:59 AM
# 9611       Terry McCartin           pac       True  01/10/2024 10:44:59 AM
# 9612       Terry McCartin           pac       True  01/10/2024 10:44:59 AM
# 9613       Terry McCartin           pac       True  01/10/2024 10:44:59 AM
# 9616       Terry McCartin           pac       True  01/10/2024 10:44:59 AM
# 9617       Terry McCartin           pac       True  01/10/2024 10:44:59 AM
# 9618       Terry McCartin           pac       True  01/10/2024 10:44:59 AM
# 9619       Terry McCartin           pac       True  01/10/2024 10:44:59 AM
# 9620       Terry McCartin           pac       True  01/10/2024 10:44:59 AM
# 9621       Terry McCartin           pac       True  01/10/2024 10:44:59 AM
# 9622       Terry McCartin           pac       True  01/10/2024 10:44:59 AM
# 9623       Terry McCartin           pac       True  01/10/2024 10:44:59 AM
# 11718        LORA HAGGARD           pac      False  11/14/2020 12:31:11 AM
# 12497      BLAIR ANDERSON           pac       True  11/14/2020 10:29:31 AM
# 13473          Jason Hoff      bonafide       True  01/11/2022 07:28:27 AM
# 15003           STAN LONG           pac      False  11/14/2020 08:39:08 AM
# 17401  JENNIFER GREGERSON           pac      False  11/13/2020 11:50:36 PM
# 17467         SHERI BAKER           pac      False  11/14/2020 02:05:09 AM
# 20537      NATHAN BRIDGES     candidate        NaN  11/13/2020 10:57:29 PM
# 28351   VIRGINIA L SORGEN     candidate        NaN  11/14/2020 05:53:37 AM
#
# [36 rows x 76 columns]

# %%
df_new_clean2_main[['committee_acronym','committee_address', 'committee_city', 'committee_county',
                    'committee_state', 'committee_zip', 'committee_email',
                     'candidate_email','contributions_amount']]
# Out:
#       committee_acronym                  committee_address    committee_city  \
# 0                   NaN                     10 SABLE COURT            SEQUIM
# 1                   NaN          620 SE 168th Avenue, N-55         VANCOUVER
# 2                   NaN          620 SE 168th Avenue, N-55         VANCOUVER
# 4                   NaN          620 SE 168th Avenue, N-55         VANCOUVER
# 13                  NaN          620 SE 168th Avenue, N-55         VANCOUVER
# ...                 ...                                ...               ...
# 52259               NaN      5426 N. Rd. 68, Ste D Box 220             Pasco
# 52260               NaN                       PO Box 27113           Seattle
# 52261               NaN                    2703 3rd street         Union Gap
# 52263               NaN                          PO Box 37  North Bonneville
# 52265               NaN  1050 Larrabee Avenue Ste 104-2009        Bellingham
#
#       committee_county committee_state committee_zip  \
# 0              CLALLAM              WA         98382
# 1                Clark              WA    98684-8428
# 2                Clark              WA    98684-8428
# 4                Clark              WA    98684-8428
# 13               Clark              WA    98684-8428
# ...                ...             ...           ...
# 52259      WALLA WALLA              WA         99301
# 52260             KING              WA         98165
# 52261           YAKIMA              WA         98903
# 52263         SKAMANIA              WA         98639
# 52265          WHATCOM              WA         98225
#
#                            committee_email  \
# 0               KEVINVANDEWEGE@HOTMAIL.COM
# 1                    LARRYDEV1@OUTLOOK.COM
# 2                    LARRYDEV1@OUTLOOK.COM
# 4                    LARRYDEV1@OUTLOOK.COM
# 13                   LARRYDEV1@OUTLOOK.COM
# ...                                    ...
# 52259  nikkitorresforstatesenate@gmail.com
# 52260                fredforport@gmail.com
# 52261                edperezjr84@gmail.com
# 52263                 voteforest@gmail.com
# 52265         janetfordistrict42@gmail.com
#
#                            candidate_email  contributions_amount
# 0               kevinvandewege@hotmail.com              32202.89
# 1                                      NaN                981.62
# 2                                      NaN              32805.76
# 4                                      NaN                  0.00
# 13                                     NaN              10130.00
# ...                                    ...                   ...
# 52259  nikkitorresforstatesenate@gmail.com              14100.00
# 52260                                  NaN                  1.07
# 52261                edperezjr84@gmail.com               1993.49
# 52263              voteforforest@gmail.com               5188.37
# 52265         janetfordistrict42@gmail.com               5565.89
#
# [22119 rows x 9 columns]

# %%
df_new_clean2_main.committee_county.unique()
# Out:
# array(['CLALLAM', 'Clark', 'Walla Walla', 'King', 'KING', 'THURSTON',
#        'Thurston', 'Spokane', 'District of Columbia', 'Various',
#        'PACIFIC', 'KITSAP', 'COWLITZ', 'Whatcom', 'BENTON', 'WHITMAN',
#        'YAKIMA', 'Snohomish', 'Pierce', 'WHATCOM', 'Benton', 'Cowlitz',
#        'Chelan', 'STEVENS', 'MASON', 'PIERCE', 'ASOTIN', 'SNOHOMISH',
#        'CLARK', 'OKANOGAN', 'LEWIS', 'Mason', 'Yakima', 'Jefferson',
#        'KITTITAS', 'Columbia', 'GRANT', 'Kittitas', 'Clackamas',
#        'Grays Harbor', 'Clallam', 'SPOKANE', 'ISLAND', 'Okanogan',
#        'CHELAN', 'WALLA WALLA', 'San Juan', 'FERRY', 'JEFFERSON',
#        'Douglas', 'Grant', 'SKAGIT', 'Skagit', 'Lewis', "Prince George's",
#        'GRAYS HARBOR', 'Kings', 'Hennepin', 'Franklin', 'New York',
#        'Wahkiakum', 'KLICKITAT', 'Clatsop', 'Kitsap', 'Montgomery',
#        'Arlington', 'WAHKIAKUM', 'Whitman', 'SAN JUAN', 'PEND OREILLE',
#        'Multnomah', 'DOUGLAS', 'ADAMS', 'GARFIELD', 'LINCOLN', 'FRANKLIN',
#        'Island', 'Blue Earth', 'Los Angeles', 'Ferry', 'Alameda',
#        'Dallas', 'Pend Oreille', 'SKAMANIA', 'Stevens', 'Harris',
#        'San Mateo', 'Collin', 'Washington', 'Sedgwick', 'Hudson',
#        'Chittenden', 'Cuyahoga', 'Lake', 'St. Louis', 'Pacific', 'McLean',
#        'Marin', 'Adams', 'Skamania', 'Fulton', 'Klickitat', 'Asotin',
#        'Garfield', 'Suffolk', 'Lincoln', 'Fairfax (city)', 'Sacramento',
#        'City of Alexandria', 'COLUMBIA'], dtype=object)

# %%
def main():
    """
    Main function to process and analyze campaign finance data
    """
    # data_path = '/content/drive/MyDrive/VAD_Final_Project/'
    # Read the data
    df_new = df_new_clean2_main

    # Clean the data
    cleaned_data = clean_campaign_finance_data(df_new)

    # Create analysis views
    analysis_views = create_dashboard_views(cleaned_data)

    # Save cleaned data
    cleaned_data.to_csv('cleaned_campaign_finance_data.csv', index=False)

    # Save analysis views
    for view_name, view_data in analysis_views.items():
        view_data.to_csv(f'{view_name}.csv', index=False)

    # Print summary of processing
    print("Data processing completed successfully!")
    print(f"Total records processed: {len(cleaned_data)}")
    print("\nUnique counties found:", cleaned_data['committee_county'].nunique())
    print("\nRecords by region:")
    print(cleaned_data['region'].value_counts())

if __name__ == "__main__":
    main()
# Out:
# <ipython-input-4-4416e1b4735a>:25: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_clean[col] = pd.to_datetime(df_clean[col], errors='coerce')
# <ipython-input-4-4416e1b4735a>:25: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_clean[col] = pd.to_datetime(df_clean[col], errors='coerce')
# <ipython-input-4-4416e1b4735a>:25: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_clean[col] = pd.to_datetime(df_clean[col], errors='coerce')
# <ipython-input-4-4416e1b4735a>:25: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_clean[col] = pd.to_datetime(df_clean[col], errors='coerce')
# <ipython-input-5-5156664e9ae3>:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   views['overview_trends'] = df.groupby(['year', 'month', 'party']).agg({
# <ipython-input-5-5156664e9ae3>:28: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   views['party_contributions'] = df.groupby(['party', 'year', 'month']).agg({
# <ipython-input-5-5156664e9ae3>:48: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   views['committee_performance'] = df.groupby(['committee_id', 'committee_category', 'party']).agg({
# <ipython-input-5-5156664e9ae3>:55: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   views['committee_trends'] = df.groupby(['committee_category', 'year', 'month']).agg({
# Data processing completed successfully!
# Total records processed: 10148
#
# Unique counties found: 40
#
# Records by region:
# region
# Puget Sound    5134
# Western WA     1596
# Central WA     1235
# Coastal        1087
# Eastern WA      835
# Other           261
# Name: count, dtype: int64

# %%
cleaned_df = pd.read_csv('cleaned_campaign_finance_data.csv')
# Out:
# <ipython-input-107-1ec80384d649>:1: DtypeWarning: Columns (32,33,45,48,49,50,51,52,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   cleaned_df = pd.read_csv('cleaned_campaign_finance_data.csv')

# %%
cleaned_df.committee_county.unique()
# Out:
# array(['CLALLAM', 'CLARK', 'WALLA WALLA', 'KING', 'THURSTON', 'SPOKANE',
#        'DISTRICT OF COLUMBIA', 'VARIOUS', 'PACIFIC', 'KITSAP', 'COWLITZ',
#        'WHATCOM', 'BENTON', 'WHITMAN', 'YAKIMA', 'SNOHOMISH', 'PIERCE',
#        'CHELAN', 'STEVENS', 'MASON', 'ASOTIN', 'OKANOGAN', 'LEWIS',
#        'JEFFERSON', 'KITTITAS', 'COLUMBIA', 'GRANT', 'CLACKAMAS',
#        'GRAYS HARBOR', 'ISLAND', 'SAN JUAN', 'FERRY', 'DOUGLAS', 'SKAGIT',
#        'PRINCE GEORGE', 'KINGS', 'HENNEPIN', 'FRANKLIN', 'NEW YORK',
#        'WAHKIAKUM', 'KLICKITAT', 'CLATSOP', 'MONTGOMERY', 'ARLINGTON',
#        'PEND OREILLE', 'MULTNOMAH', 'ADAMS', 'GARFIELD', 'LINCOLN',
#        'BLUE EARTH', 'LOS ANGELES', 'ALAMEDA', 'DALLAS', 'SKAMANIA',
#        'HARRIS', 'SAN MATEO', 'COLLIN', 'WASHINGTON', 'SEDGWICK',
#        'HUDSON', 'CHITTENDEN', 'CUYAHOGA', 'LAKE', 'ST. LOUIS', 'MCLEAN',
#        'MARIN', 'FULTON', 'SUFFOLK', 'FAIRFAX (CITY)', 'SACRAMENTO',
#        'ALEXANDRIA'], dtype=object)

# %%
for i in cleaned_df.isnull().sum():
  print(i)
# Out:
# 0
# 0
# 0
# 10938
# 17577
# 21051
# 21034
# 0
# 337
# 0
# 0
# 0
# 18485
# 1
# 1
# 0
# 4516
# 0
# 1235
# 11154
# 5046
# 10937
# 10937
# 10540
# 10549
# 10908
# 10542
# 12874
# 10944
# 10937
# 0
# 0
# 18594
# 18300
# 17495
# 13507
# 0
# 8943
# 4246
# 21056
# 21056
# 21056
# 11956
# 13789
# 0
# 18594
# 0
# 10455
# 20621
# 20231
# 20158
# 20126
# 19464
# 471
# 471
# 4990
# 471
# 6616
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 263
# 0
# 872
# 10937
# 0
# 18583
# 337
# 0
# 10119
# 0
# 0
# 0
# 0
# 0
# 337
# 337
# 337
# 2916
